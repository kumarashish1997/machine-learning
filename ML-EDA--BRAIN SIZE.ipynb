# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('brain_size.csv',sep=';',na_values='.')
df=pd.DataFrame(df)
df
# Out:
#     id  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0    1  Female   133  132  124   118.0    64.5     816932
# 1    2    Male   140  150  124     NaN    72.5    1001121
# 2    3    Male   139  123  150   143.0    73.3    1038437
# 3    4    Male   133  129  128   172.0    68.8     965353
# 4    5  Female   137  132  134   147.0    65.0     951545
# 5    6  Female    99   90  110   146.0    69.0     928799
# 6    7  Female   138  136  131   138.0    64.5     991305
# 7    8  Female    92   90   98   175.0    66.0     854258
# 8    9    Male    89   93   84   134.0    66.3     904858
# 9   10    Male   133  114  147   172.0    68.8     955466
# 10  11  Female   132  129  124   118.0    64.5     833868
# 11  12    Male   141  150  128   151.0    70.0    1079549
# 12  13    Male   135  129  124   155.0    69.0     924059
# 13  14  Female   140  120  147   155.0    70.5     856472
# 14  15  Female    96  100   90   146.0    66.0     878897
# ...

# %%
df.shape
# Out:
# (40, 8)

# %%
df.dtypes
# Out:
# id             int64
# Gender        object
# FSIQ           int64
# VIQ            int64
# PIQ            int64
# Weight       float64
# Height       float64
# MRI_Count      int64
# dtype: object

# %% [markdown]
# # removing nullvalues

# %% [raw]
# if there are some number of null values then we can removed it but if they are large number then we will use another method further

# %%
df.isnull().sum()
# Out:
# id           0
# Gender       0
# FSIQ         0
# VIQ          0
# PIQ          0
# Weight       2
# Height       1
# MRI_Count    0
# dtype: int64

# %%
ds=df.drop([1,20],axis=0)
ds
# Out:
#     id  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0    1  Female   133  132  124   118.0    64.5     816932
# 2    3    Male   139  123  150   143.0    73.3    1038437
# 3    4    Male   133  129  128   172.0    68.8     965353
# 4    5  Female   137  132  134   147.0    65.0     951545
# 5    6  Female    99   90  110   146.0    69.0     928799
# 6    7  Female   138  136  131   138.0    64.5     991305
# 7    8  Female    92   90   98   175.0    66.0     854258
# 8    9    Male    89   93   84   134.0    66.3     904858
# 9   10    Male   133  114  147   172.0    68.8     955466
# 10  11  Female   132  129  124   118.0    64.5     833868
# 11  12    Male   141  150  128   151.0    70.0    1079549
# 12  13    Male   135  129  124   155.0    69.0     924059
# 13  14  Female   140  120  147   155.0    70.5     856472
# 14  15  Female    96  100   90   146.0    66.0     878897
# 15  16  Female    83   71   96   135.0    68.0     865363
# ...

# %%
ds.shape
# Out:
# (38, 8)

# %% [markdown]
# # SUMMARY OF STATISTIC

# %%
ds.describe()
# Out:
#               id        FSIQ         VIQ         PIQ      Weight     Height  \
# count  38.000000   38.000000   38.000000   38.000000   38.000000  38.000000
# mean   20.973684  113.552632  112.131579  111.342105  151.052632  68.421053
# std    11.600296   23.815391   22.939605   22.597867   23.478509   3.993790
# min     1.000000   77.000000   71.000000   72.000000  106.000000  62.000000
# 25%    11.250000   90.250000   90.250000   89.250000  135.250000  66.000000
# 50%    21.000000  116.500000  113.000000  115.000000  146.500000  68.000000
# 75%    30.750000  135.000000  129.000000  128.000000  172.000000  70.375000
# max    40.000000  144.000000  150.000000  150.000000  192.000000  77.000000
#
#           MRI_Count
# count  3.800000e+01
# mean   9.067542e+05
# std    7.256175e+04
# min    7.906190e+05
# 25%    8.548115e+05
# 50%    9.053990e+05
# 75%    9.495405e+05
# max    1.079549e+06

# %% [raw]
# KEY OBSERVATION:
# right skew-->FSIQ,VIQ,PIQ,Weight,Height
# outliers-->VIQ,Weight

# %% [markdown]
# # TO CHECK CORRELATION

# %%
ds_corr=ds.corr()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(ds_corr,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # UNIVARIENT ANALYSIS

# %%
ds.plot(kind='box',subplots=True,layout=(2,4))
# Out:
# id              AxesSubplot(0.125,0.536818;0.168478x0.343182)
# FSIQ         AxesSubplot(0.327174,0.536818;0.168478x0.343182)
# VIQ          AxesSubplot(0.529348,0.536818;0.168478x0.343182)
# PIQ          AxesSubplot(0.731522,0.536818;0.168478x0.343182)
# Weight             AxesSubplot(0.125,0.125;0.168478x0.343182)
# Height          AxesSubplot(0.327174,0.125;0.168478x0.343182)
# MRI_Count       AxesSubplot(0.529348,0.125;0.168478x0.343182)
# dtype: object

# %%
for i in ds.columns:
    plt.figure()
    plt.hist(ds[i])

# %% [markdown]
# # BI-VARIENT ANALYSIS

# %%
a=ds.iloc[:,2:7]
b=ds.iloc[:,2:]

# %%
for i in a:
    plt.figure()
    plt.scatter(x=a[i],y=ds['MRI_Count'])

# %%
sns.pairplot(ds)

# %% [markdown]
# # REMOVING OUTLIERS

# %%
from scipy.stats import zscore
z=np.abs(zscore(b))
z
# Out:
#         FSIQ       VIQ       PIQ    Weight    Height  MRI_Count
# 0   0.827550  0.877745  0.567656  1.426680  0.994966   1.254489
# 2   1.082869  0.480144  1.733651  0.347583  1.238032   1.839130
# 3   0.827550  0.745211  0.747040  0.904170  0.096158   0.818412
# 4   0.997763  0.877745  1.016115  0.174927  0.868092   0.625565
# 5   0.619262  0.977727  0.060188  0.218091  0.146908   0.307886
# 6   1.040316  1.054457  0.881577  0.563402  0.994966   1.180867
# 7   0.917136  0.977727  0.598340  1.033661  0.614342   0.733181
# 8   1.044795  0.845193  1.226183  0.736058  0.538217   0.026483
# 9   0.827550  0.082543  1.599113  0.904170  0.096158   0.680327
# 10  0.784996  0.745211  0.567656  1.426680  0.994966   1.017955
# 11  1.167976  1.672947  0.747040  0.002272  0.400658   2.413315
# 12  0.912656  0.745211  0.567656  0.170384  0.146908   0.241685
# 13  1.125423  0.347610  1.599113  0.170384  0.527533   0.702259
# 14  0.746922  0.535948  0.957108  0.218091  0.614342   0.389063
# ...

# %%
np.where(z>3)
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
ds_new=ds[(z<3).all(axis=1)]
ds_new
# Out:
#     id  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0    1  Female   133  132  124   118.0    64.5     816932
# 2    3    Male   139  123  150   143.0    73.3    1038437
# 3    4    Male   133  129  128   172.0    68.8     965353
# 4    5  Female   137  132  134   147.0    65.0     951545
# 5    6  Female    99   90  110   146.0    69.0     928799
# 6    7  Female   138  136  131   138.0    64.5     991305
# 7    8  Female    92   90   98   175.0    66.0     854258
# 8    9    Male    89   93   84   134.0    66.3     904858
# 9   10    Male   133  114  147   172.0    68.8     955466
# 10  11  Female   132  129  124   118.0    64.5     833868
# 11  12    Male   141  150  128   151.0    70.0    1079549
# 12  13    Male   135  129  124   155.0    69.0     924059
# 13  14  Female   140  120  147   155.0    70.5     856472
# 14  15  Female    96  100   90   146.0    66.0     878897
# 15  16  Female    83   71   96   135.0    68.0     865363
# ...

# %%
ds.shape
# Out:
# (38, 8)

# %%
ds_new.shape
# Out:
# (38, 8)

# %% [markdown]
# # There are  no outliers present in data
